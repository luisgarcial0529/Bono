# %% [markdown]
# <a href="https://colab.research.google.com/github/datascience-uniandes/data-quality-tutorial/blob/master/data-quality-tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Quality tutorial
#
# MINE-4101: Applied Data Science
# Univerisdad de los Andes
#
# Dataset: Homicides Colombia
# Source: [datos.gov.co](datos.gov.co)
#
# Last update: September, 2022

# %%
# !pip install pylev
# Out:
# Requirement already satisfied: pylev in c:\users\lgarcia\anaconda3\lib\site-packages (1.4.0)

# %%
# Importing required libraries

import re
from random import randint
from datetime import datetime
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

import pylev

# %%
# Parameter for showing all columns when printing a dataframe
pd.set_option('display.max_columns', None)

# %%
# Loading data
homicides_df = pd.read_csv("./data/homicides.csv")

# %%
# Printing the dataset dimensions
homicides_df.shape
# Out:
# (12400, 22)

# %%
# Printing column data types
homicides_df.dtypes
# Out:
# FECHA                 object
# DEPARTAMENTO          object
# MUNICIPIO             object
# DIA                   object
# HORA                  object
# BARRIO                object
# ZONA                  object
# CLASE DE SITIO        object
# ARMA O MEDIO          object
# MOVIL VICTIMA         object
# MOVIL AGRESOR         object
# EDAD                 float64
# GENERO                object
# ESTADO CIVIL          object
# CLASE EMPLEADO        object
# PROFESION             object
# ESCOLARIDAD           object
# PAIS NACE             object
# CODIGO DANE          float64
# AÑO DE NACIMIENTO    float64
# CÉDULA                object
# CORREO                object
# dtype: object

# %%
homicides_df.head()
# Out:
#                     FECHA DEPARTAMENTO      MUNICIPIO     DIA   HORA  \
# 0  01/01/2021 12:00:00 AM    ANTIOQUIA          AMAGÁ  Jueves   6:00
# 1  01/01/2021 12:00:00 AM    ANTIOQUIA        BARBOSA  Jueves   9:00
# 2  01/01/2021 12:00:00 AM    ANTIOQUIA       EL BAGRE  Jueves  19:00
# 3  01/01/2021 12:00:00 AM    ANTIOQUIA         JARDÍN  Jueves  11:20
# 4  01/01/2021 12:00:00 AM    ANTIOQUIA  MEDELLÍN (CT)   Juees  15:00
#
#                      BARRIO    ZONA                      CLASE DE SITIO  \
# 0                 EL VOLCAN   RURAL                              TIENDA
# 1            VDA. MATASANOS   RURAL                       VIAS PUBLICAS
# 2             PUERTO CLAVER   RURAL                  FINCAS Y SIMILARES
# 3                CRISTIANIA   RURAL                  FINCAS Y SIMILARES
# 4  PICACHITO CNO REPORTADO6  URBANA  FRENTE A RESIDENCIAS - VIA PUBLICA
#
#    ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO ESTADO CIVIL  \
# 0   ARMA BLANCA         A PIE         A PIE  44.0  MASCULINO       CASADO
# 1   ARMA BLANCA         A PIE         A PIE  30.0  MASCULINO      SOLTERO
# 2   ARMA BLANCA         A PIE         A PIE  33.0  MASCULINO  UNION LIBRE
# 3   ARMA BLANCA         A PIE         A PIE  40.0  MASCULINO       CASADO
# 4  CONTUNDENTES         A PIE         A PIE  66.0  MASCULINO  UNION LIBRE
#
#   CLASE EMPLEADO     PROFESION ESCOLARIDAD     PAIS NACE  CODIGO DANE  \
# 0  INDEPENDIENTE  NO REPORTADO    PRIMARIA      COLOMBIA    5030000.0
# 1    DESEMPLEADO  NO REPORTADO  SECUNDARIA  NO REPORTADO    5079000.0
# 2     AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA    5250000.0
# 3     AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA    5364000.0
# 4    DESEMPLEADO  NO REPORTADO    PRIMARIA      COLOMBIA    5001000.0
#
#    AÑO DE NACIMIENTO  CÉDULA                      CORREO
# 0             1971.0  42-908  agbnqg2122@unidatos.edu.co
# 1             1985.0  15-183        rbkeui3584@gmail.com
# 2             1982.0  84-786  aorkhf9155@unidatos.edu.co
# 3             1975.0  31-289  dhtemr6623@unidatos.edu.co
# 4             1949.0  66-363  artatj9268@unidatos.edu.co

# %%
# Creating a lambda expression for datetime parsing
dateparse = lambda x: datetime.strptime(x, "%m/%d/%Y %H:%M:%S %p")

# %%
# Creating a function for validating which value is causing the previous error
def error_in_format(x):
    try:
        datetime.strptime(x, "%m/%d/%Y %H:%M:%S %p")
        return False
    except:
        return True

# %%
# Using the function for validation
homicides_df.loc[homicides_df["FECHA"].apply(error_in_format)]

# THE LAST ROW IS CAUSING THE ERROR
# Out:
#        FECHA DEPARTAMENTO MUNICIPIO  DIA HORA BARRIO ZONA CLASE DE SITIO  \
# 12399  TOTAL          NaN       NaN  NaN  NaN    NaN  NaN            NaN
#
#       ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD GENERO ESTADO CIVIL  \
# 12399          NaN           NaN           NaN   NaN    NaN          NaN
#
#       CLASE EMPLEADO PROFESION ESCOLARIDAD PAIS NACE  CODIGO DANE  \
# 12399            NaN       NaN         NaN       NaN          NaN
#
#        AÑO DE NACIMIENTO CÉDULA CORREO
# 12399                NaN    NaN    NaN

# %%
# Deleting a row by its index
homicides_df.drop(12399, inplace = True)

# %%
# Trying to parse the datetime string again
homicides_df["FECHA"] = homicides_df["FECHA"].apply(dateparse)

# %%
# Counting homicides by hour
homicides_df["FECHA"].dt.hour.value_counts()

# All datetime hour parts are the same
# Out:
# 12    12399
# Name: FECHA, dtype: int64

# %%
# The homicide hour is available in a different column!
# Merging both columns
homicides_df["FECHA"] = homicides_df["FECHA"].astype(str).apply(lambda x: x[:11]) + homicides_df["HORA"]

# %%
del homicides_df["HORA"]

# %%
homicides_df["FECHA"].head()
# Out:
# 0     2021-01-01 6:00
# 1     2021-01-01 9:00
# 2    2021-01-01 19:00
# 3    2021-01-01 11:20
# 4    2021-01-01 15:00
# Name: FECHA, dtype: object

# %%
# Making a new expression for datetime parsing
dateparse = lambda x: datetime.strptime(x, "%Y-%m-%d %H:%M")

# %%
# Applying the expression
homicides_df["FECHA"] = homicides_df["FECHA"].apply(dateparse)

# %%
homicides_df.dtypes
# Out:
# FECHA                datetime64[ns]
# DEPARTAMENTO                 object
# MUNICIPIO                    object
# DIA                          object
# BARRIO                       object
# ZONA                         object
# CLASE DE SITIO               object
# ARMA O MEDIO                 object
# MOVIL VICTIMA                object
# MOVIL AGRESOR                object
# EDAD                        float64
# GENERO                       object
# ESTADO CIVIL                 object
# CLASE EMPLEADO               object
# PROFESION                    object
# ESCOLARIDAD                  object
# PAIS NACE                    object
# CODIGO DANE                 float64
# AÑO DE NACIMIENTO           float64
# CÉDULA                       object
# CORREO                       object
# dtype: object

# %%
homicides_df.head()
# Out:
#                 FECHA DEPARTAMENTO      MUNICIPIO     DIA  \
# 0 2021-01-01 06:00:00    ANTIOQUIA          AMAGÁ  Jueves
# 1 2021-01-01 09:00:00    ANTIOQUIA        BARBOSA  Jueves
# 2 2021-01-01 19:00:00    ANTIOQUIA       EL BAGRE  Jueves
# 3 2021-01-01 11:20:00    ANTIOQUIA         JARDÍN  Jueves
# 4 2021-01-01 15:00:00    ANTIOQUIA  MEDELLÍN (CT)   Juees
#
#                      BARRIO    ZONA                      CLASE DE SITIO  \
# 0                 EL VOLCAN   RURAL                              TIENDA
# 1            VDA. MATASANOS   RURAL                       VIAS PUBLICAS
# 2             PUERTO CLAVER   RURAL                  FINCAS Y SIMILARES
# 3                CRISTIANIA   RURAL                  FINCAS Y SIMILARES
# 4  PICACHITO CNO REPORTADO6  URBANA  FRENTE A RESIDENCIAS - VIA PUBLICA
#
#    ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO ESTADO CIVIL  \
# 0   ARMA BLANCA         A PIE         A PIE  44.0  MASCULINO       CASADO
# 1   ARMA BLANCA         A PIE         A PIE  30.0  MASCULINO      SOLTERO
# 2   ARMA BLANCA         A PIE         A PIE  33.0  MASCULINO  UNION LIBRE
# 3   ARMA BLANCA         A PIE         A PIE  40.0  MASCULINO       CASADO
# 4  CONTUNDENTES         A PIE         A PIE  66.0  MASCULINO  UNION LIBRE
#
#   CLASE EMPLEADO     PROFESION ESCOLARIDAD     PAIS NACE  CODIGO DANE  \
# 0  INDEPENDIENTE  NO REPORTADO    PRIMARIA      COLOMBIA    5030000.0
# 1    DESEMPLEADO  NO REPORTADO  SECUNDARIA  NO REPORTADO    5079000.0
# 2     AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA    5250000.0
# 3     AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA    5364000.0
# 4    DESEMPLEADO  NO REPORTADO    PRIMARIA      COLOMBIA    5001000.0
#
#    AÑO DE NACIMIENTO  CÉDULA                      CORREO
# 0             1971.0  42-908  agbnqg2122@unidatos.edu.co
# 1             1985.0  15-183        rbkeui3584@gmail.com
# 2             1982.0  84-786  aorkhf9155@unidatos.edu.co
# 3             1975.0  31-289  dhtemr6623@unidatos.edu.co
# 4             1949.0  66-363  artatj9268@unidatos.edu.co

# %%
# Creating a dictionary representing the valid departments for Colombia
departments_list = ['ANTIOQUIA', 'ATLÁNTICO', 'BOLÍVAR', 'BOYACÁ', 'CALDAS', 'CAQUETÁ',
       'CASANARE', 'CAUCA', 'CESAR', 'CHOCÓ', 'CÓRDOBA', 'META',
       'CUNDINAMARCA', 'HUILA', 'MAGDALENA', 'NARIÑO', 'PUTUMAYO',
       'RISARALDA', 'SANTANDER', 'SUCRE', 'TOLIMA', 'VALLE',
       'NORTE DE SANTANDER', 'GUAJIRA', 'QUINDÍO', 'SAN ANDRÉS Y PROVIDENCIA', 'ARAUCA',
       'GUAINÍA', 'VICHADA', 'VAUPÉS', 'GUAVIARE', 'AMAZONAS']

# %%
# Finding values not matching with the dictionary
homicides_df.loc[~homicides_df["DEPARTAMENTO"].isin(departments_list), "DEPARTAMENTO"].unique()
# Out:
# array(['SAN ANDRÉS', 'N. DE SANTANDER'], dtype=object)

# %% [markdown]
# <span style="color:red">TODO: Replace the values identified as error to a valid value from the dictionary</span>
#
# <span style="color:red">Hint: You can use the replace() pandas function</span>

# %%
# Copio el DF para no alterar el original

homicides_df['DEPARTAMENTO'].replace('SAN ANDRÉS Y PROVIDENCIA','SAN ANDRÉS', inplace=True)
homicides_df['DEPARTAMENTO'].replace('SAN ANDRÉS','SAN ANDRÉS Y PROVIDENCIA', inplace=True)
homicides_df['DEPARTAMENTO'].replace('N. DE SANTANDER','NORTE DE SANTANDER', inplace=True)

# Verifico que no esten datos por fuera de la serie 

homicides_df.loc[~homicides_df["DEPARTAMENTO"].isin(departments_list), "DEPARTAMENTO"].unique()
# Out:
# array([], dtype=object)

# %%
# Detecting duplicates by "CÉDULA" column
duplicates_by_cedula = homicides_df.loc[homicides_df["CÉDULA"].duplicated(keep = False)]

# %%
duplicates_by_cedula.shape
# Out:
# (1627, 21)

# %%
# Showing some examples
duplicates_by_cedula.sort_values("CÉDULA", ascending = True).head(6)
# Out:
#                     FECHA DEPARTAMENTO      MUNICIPIO      DIA  \
# 4041  2021-05-03 23:30:00        CAUCA       EL TAMBO  Domingo
# 3810  2021-04-26 03:00:00    ANTIOQUIA   SAN JERÓNIMO  Domingo
# 693   2021-01-19 05:30:00    ANTIOQUIA         SALGAR    Lunes
# 10796 2021-11-20 03:00:00        VALLE      CALI (CT)  Viernes
# 2386  2021-03-14 02:00:00         META  FUENTE DE ORO   Sábado
# 138   2021-01-02 06:20:00        CAUCA         SOTARA  Viernes
#
#                     BARRIO    ZONA                      CLASE DE SITIO  \
# 4041           LA VICTORIA   RURAL         BARES, CANTINAS Y SIMILARES
# 3810              LA PLAYA  URBANA  HOTELES, RESIDENCIAS, Y SIMILARES.
# 693              LA HABANA  URBANA                       VIAS PUBLICAS
# 10796   POTRERO GRANDE E21  URBANA                       VIAS PUBLICAS
# 2386   VEREDA PUERTO NUEVO   RURAL         BARES, CANTINAS Y SIMILARES
# 138                 CENTRO   RURAL                       VIAS PUBLICAS
#
#              ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO  \
# 4041        ARMA DE FUEGO         A PIE         A PIE  45.0  MASCULINO
# 3810   CUERDA/SOGA/CADENA         A PIE         A PIE  25.0  MASCULINO
# 693         ARMA DE FUEGO         A PIE         A PIE  58.0  MASCULINO
# 10796       ARMA DE FUEGO         A PIE         A PIE  21.0  MASCULINO
# 2386          ARMA BLANCA         A PIE         A PIE  42.0  MASCULINO
# 138           ARMA BLANCA         A PIE         A PIE  22.0  MASCULINO
#
#       ESTADO CIVIL       CLASE EMPLEADO     PROFESION ESCOLARIDAD PAIS NACE  \
# 4041   UNION LIBRE           AGRICULTOR  NO REPORTADO    PRIMARIA  COLOMBIA
# 3810       SOLTERO        INDEPENDIENTE  NO REPORTADO  SECUNDARIA  COLOMBIA
# 693        SOLTERO           AGRICULTOR  NO REPORTADO    PRIMARIA  COLOMBIA
# 10796      SOLTERO  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA  COLOMBIA
# 2386       SOLTERO        INDEPENDIENTE  NO REPORTADO    PRIMARIA  COLOMBIA
# 138        SOLTERO    EMPLEADO EJERCITO  NO REPORTADO  SECUNDARIA  COLOMBIA
#
#        CODIGO DANE  AÑO DE NACIMIENTO  CÉDULA                      CORREO
# 4041    19256000.0             1970.0  10-048        aitufn1227@gmail.com
# 3810     5656000.0             1990.0  10-048  ibbcpu2509@unidatos.edu.co
# 693      5642000.0               57.0  10-079  unhoqj1172@unidatos.edu.co
# 10796   76001000.0             1994.0  10-079  iknnoj8430@unidatos.edu.co
# 2386    50287000.0             1973.0  10-255  afompq7113@unidatos.edu.co
# 138     19760000.0             1993.0  10-255  cobgqs8819@unidatos.edu.co

# %% [markdown]
# <span style="color:red">TODO: Delete records with "CÉDULA" duplicated</span>
#
# <span style="color:red">Hint: You can use drop_duplicates() pandas function.</span>

# %%
# No estoy de acuerdo con borrar porque son personas diferentes en la mayoria de casos, a pesar que tienen la misma cédula son registros diferentes. 

# Yo haría lo siguiente:
copyHomicides_df = duplicates_by_cedula
copyHomicides_df.drop_duplicates(keep='first', inplace=True)
copyHomicides_df.shape

# Como se evidencia, no hay borrado de datos. Ahora, lo solicitado: 
duplicates_by_cedula.drop_duplicates(subset='CÉDULA',keep='first', inplace=True)
duplicates_by_cedula.shape

#Con esto quedan en 791 registros únicamente.
# Out:
# (791, 21)

# %%
# Using regular expressions for validating if "CÉDULA" values match the pattern XX-XXX
cedula_malformed = homicides_df.loc[homicides_df["CÉDULA"].apply(lambda x: (re.match("\d{2}-\d{3}", x) is None))]

# %%
cedula_malformed.shape
# Out:
# (28, 21)

# %%
cedula_malformed.head(6)
# Out:
#                    FECHA DEPARTAMENTO          MUNICIPIO      DIA  \
# 172  2021-01-03 11:00:00         META            MESETAS   Sábado
# 1114 2021-02-01 12:30:00    ATLÁNTICO  BARRANQUILLA (CT)  Domingo
# 2119 2021-03-06 15:30:00        VALLE          CALI (CT)  Viernes
# 3309 2021-04-11 10:30:00      CAQUETÁ     FLORENCIA (CT)   Sávado
# 3409 2021-04-13 23:20:00      CÓRDOBA            SAHAGÚN    Lunes
# 3588 2021-04-19 20:00:00      BOLÍVAR     CARTAGENA (CT)  Domingo
#
#                             BARRIO    ZONA         CLASE DE SITIO  \
# 172                VEREDA EL CAFRE   RURAL         ZONA SELVÁTICA
# 1114                        LA LUZ  URBANA          VIAS PUBLICAS
# 2119           QUINTAS DEL SOL E14  URBANA  DENTRO DE LA VIVIENDA
# 3309                   VIA MORELIA   RURAL               CARCELES
# 3409  CORREGIMIENTO DE BAJO GRANDE  URBANA               BILLARES
# 3588                  LA ESPERANZA  URBANA          VIAS PUBLICAS
#
#           ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO  \
# 172   MINA ANTIPERSONA         A PIE         A PIE  24.0  MASCULINO
# 1114     ARMA DE FUEGO         A PIE         A PIE  29.0  MASCULINO
# 2119       ARMA BLANCA         A PIE         A PIE  20.0   FEMENINO
# 3309         CORTANTES         A PIE         A PIE  23.0  MASCULINO
# 3409      CONTUNDENTES         A PIE         A PIE  49.0  MASCULINO
# 3588     ARMA DE FUEGO         A PIE         A PIE  45.0  MASCULINO
#
#      ESTADO CIVIL       CLASE EMPLEADO     PROFESION   ESCOLARIDAD  \
# 172       SOLTERO    EMPLEADO EJERCITO  NO REPORTADO    SECUNDARIA
# 1114      SOLTERO        INDEPENDIENTE  NO REPORTADO      PRIMARIA
# 2119  UNION LIBRE  EMPLEADO PARTICULAR  NO REPORTADO    SECUNDARIA
# 3309      SOLTERO        INDEPENDIENTE  NO REPORTADO      PRIMARIA
# 3409      SOLTERO        INDEPENDIENTE  NO REPORTADO    SECUNDARIA
# 3588      SOLTERO          DESEMPLEADO  NO REPORTADO  NO REPORTADO
#
#          PAIS NACE  CODIGO DANE  AÑO DE NACIMIENTO  CÉDULA  \
# 172       COLOMBIA   50330000.0             1991.0  680-21
# 1114      COLOMBIA    8001000.0             1986.0  140-17
# 2119      COLOMBIA   76001000.0             1995.0  975-31
# 3309      COLOMBIA   18001000.0             1992.0  348-66
# 3409      COLOMBIA   23660000.0             1966.0  496-18
# 3588  NO REPORTADO   13001000.0             1970.0  188-03
#
#                           CORREO
# 172         oohghd8899@gmail.com
# 1114  correo5853@colombia.gov.co
# 2119  ohbqrk3631@unidatos.edu.co
# 3309  pdkqur8407@unidatos.edu.co
# 3409  fdbbeo6751@unidatos.edu.co
# 3588  diebuo5651@unidatos.edu.co

# %% [markdown]
# <span style="color:red">TODO: Fix the malformed "CÉDULA" values.</span>

# %%
# Parto de la base que para corregir la Cédula se debe correr el guión un caracter. Por esto copio el dataSet para hacer la transformación quitando el guión y 
# e insertando el guión en la posición 3.

dfPrueba = cedula_malformed
dfPrueba['CÉDULA'].replace('-','',regex=True,inplace=True)
dfPrueba['CÉDULA1']=dfPrueba['CÉDULA'].str[:2]
dfPrueba['CÉDULA2']=dfPrueba['CÉDULA'].str[-3:]
cedula_malformed['CÉDULA']=dfPrueba['CÉDULA1']+'-'+dfPrueba['CÉDULA2']

# %%
cedula_malformed
# Out:
#                     FECHA  DEPARTAMENTO            MUNICIPIO        DIA  \
# 172   2021-01-03 11:00:00          META              MESETAS     Sábado
# 1114  2021-02-01 12:30:00     ATLÁNTICO    BARRANQUILLA (CT)    Domingo
# 2119  2021-03-06 15:30:00         VALLE            CALI (CT)    Viernes
# 3309  2021-04-11 10:30:00       CAQUETÁ       FLORENCIA (CT)     Sávado
# 3409  2021-04-13 23:20:00       CÓRDOBA              SAHAGÚN      Lunes
# 3588  2021-04-19 20:00:00       BOLÍVAR       CARTAGENA (CT)    Domingo
# 4565  2021-05-18 03:20:00      CASANARE                 MANÍ       lune
# 4587  2021-05-18 10:15:00         VALLE  GUADALAJARA DE BUGA      Lumes
# 4971  2021-05-30 13:22:00         VALLE            CALI (CT)     Sábado
# 5372  2021-06-09 10:50:00        NARIÑO           PASTO (CT)     Msrtes
# 5532  2021-06-14 21:00:00  CUNDINAMARCA            ZIPAQUIRÁ    domungo
# 5834  2021-06-21 12:20:00         VALLE            CALI (CT)    Domingo
# 5849  2021-06-22 07:10:00     ANTIOQUIA        MEDELLÍN (CT)      Lunes
# 6315  2021-07-05 20:15:00         VALLE            CALI (CT)    Domingo
# 7885  2021-08-23 09:00:00        CALDAS                NEIRA    Domingo
# 8094  2021-08-29 08:40:00       CÓRDOBA             CANALETE      sábad
# 8183  2021-08-31 15:00:00  CUNDINAMARCA     BOGOTÁ D.C. (CT)      Lunes
# 8223  2021-09-02 20:48:00     ANTIOQUIA            SAN PEDRO  Miércoles
# 9033  2021-09-27 09:40:00       CÓRDOBA        MONTERÍA (CT)    Domingo
# 9751  2021-10-19 17:00:00         VALLE          LA VICTORIA      Lunes
# 10205 2021-11-03 12:45:00     RISARALDA          LA VIRGINIA     Martes
# 10625 2021-11-15 21:30:00       QUINDÍO         ARMENIA (CT)    Domingo
# 10689 2021-11-17 22:42:00         CAUCA         POPAYÁN (CT)     Martes
# 10959 2021-11-25 21:53:00     ANTIOQUIA        MEDELLÍN (CT)  Miércoles
# 11020 2021-11-27 18:00:00     MAGDALENA              CIÉNAGA    Viernes
# 11740 2021-12-16 15:30:00     ANTIOQUIA                YONDÓ  Miwrcoles
# 11957 2021-12-22 01:45:00     ANTIOQUIA        MEDELLÍN (CT)     Martes
# 12206 2021-12-26 22:55:00         VALLE            CALI (CT)     Sábado
#
#                                  BARRIO    ZONA  \
# 172                     VEREDA EL CAFRE   RURAL
# 1114                             LA LUZ  URBANA
# 2119                QUINTAS DEL SOL E14  URBANA
# 3309                        VIA MORELIA   RURAL
# 3409       CORREGIMIENTO DE BAJO GRANDE  URBANA
# 3588                       LA ESPERANZA  URBANA
# 4565                    CENTRAL DE MANI  URBANA
# 4587   VIA BUGA NO REPORTADO MEDIACANOA   RURAL
# 4971                PUERTAS DEL SOL E14  URBANA
# 5372                            RIVIERA  URBANA
# 5532                      VER. RIO FRIO  URBANA
# 5834                 LAUREANO GOMEZ E15  URBANA
# 5849        EL CHAGUALO CNO REPORTADO10  URBANA
# 6315                    MARROQUIN I E14  URBANA
# 7885                      VDA EL GUINEO   RURAL
# 8094                    VEREDA EL CLAVO   RURAL
# 8183            SUMAPAZ ENO REPORTADO20   RURAL
# 8223                          EL ALTICO  URBANA
# 9033                         LA PRADERA  URBANA
# 9751                         OCCIDENTAL  URBANA
# 10205                      LA MAGDALENA  URBANA
# 10625             LA FACHADA I,II Y III  URBANA
# 10689                            PALACE  URBANA
# 10959         VILLA TINA CNO REPORTADO8  URBANA
# 11020                         CORDOBITA   RURAL
# 11740                  VDA. CAÑO BLANCO   RURAL
# 11957         SAN PABLO CNO REPORTADO15  URBANA
# 12206             ALFONSO B. ARAGON E14  URBANA
#
#                            CLASE DE SITIO      ARMA O MEDIO   MOVIL VICTIMA  \
# 172                        ZONA SELVÁTICA  MINA ANTIPERSONA           A PIE
# 1114                        VIAS PUBLICAS     ARMA DE FUEGO           A PIE
# 2119                DENTRO DE LA VIVIENDA       ARMA BLANCA           A PIE
# 3309                             CARCELES         CORTANTES           A PIE
# 3409                             BILLARES      CONTUNDENTES           A PIE
# 3588                        VIAS PUBLICAS     ARMA DE FUEGO           A PIE
# 4565   HOTELES, RESIDENCIAS, Y SIMILARES.       ARMA BLANCA           A PIE
# 4587                        VIAS PUBLICAS     ARMA DE FUEGO           A PIE
# 4971                        VIAS PUBLICAS     ARMA DE FUEGO           A PIE
# 5372                                 RIOS       ARMA BLANCA           A PIE
# 5532                        VIAS PUBLICAS       ARMA BLANCA           A PIE
# 5834                        VIAS PUBLICAS     ARMA DE FUEGO           A PIE
# 5849                                 RIOS       ARMA BLANCA           A PIE
# 6315   FRENTE A RESIDENCIAS - VIA PUBLICA     ARMA DE FUEGO           A PIE
# 7885                        VIAS PUBLICAS     ARMA DE FUEGO        VEHICULO
# 8094                   FINCAS Y SIMILARES     ARMA DE FUEGO           A PIE
# 8183                        VIAS PUBLICAS     ARMA DE FUEGO           A PIE
# 8223                        VIAS PUBLICAS       ARMA BLANCA           A PIE
# 9033                        VIAS PUBLICAS     ARMA DE FUEGO  CONDUCTOR TAXI
# 9751                        VIAS PUBLICAS     ARMA DE FUEGO           A PIE
# 10205                       VIAS PUBLICAS     ARMA DE FUEGO           A PIE
# 10625  FRENTE A RESIDENCIAS - VIA PUBLICA     ARMA DE FUEGO           A PIE
# 10689                 CASAS DE HABITACION       ARMA BLANCA           A PIE
# 10959                       VIAS PUBLICAS     ARMA DE FUEGO           A PIE
# 11020                       VIAS PUBLICAS       ARMA BLANCA           A PIE
# 11740                           CARRETERA     ARMA DE FUEGO           A PIE
# 11957                       VIAS PUBLICAS       ARMA BLANCA           A PIE
# 12206                       VIAS PUBLICAS     ARMA DE FUEGO           A PIE
#
#                MOVIL AGRESOR  EDAD     GENERO  ESTADO CIVIL  \
# 172                    A PIE  24.0  MASCULINO       SOLTERO
# 1114                   A PIE  29.0  MASCULINO       SOLTERO
# 2119                   A PIE  20.0   FEMENINO   UNION LIBRE
# 3309                   A PIE  23.0  MASCULINO       SOLTERO
# 3409                   A PIE  49.0  MASCULINO       SOLTERO
# 3588                   A PIE  45.0  MASCULINO       SOLTERO
# 4565                   A PIE  27.0   FEMENINO       SOLTERO
# 4587                   A PIE  25.0  MASCULINO       SOLTERO
# 4971                   A PIE  35.0  MASCULINO   UNION LIBRE
# 5372                   A PIE  20.0  MASCULINO  NO REPORTADO
# 5532                   A PIE  45.0  MASCULINO   UNION LIBRE
# 5834                   A PIE  20.0  MASCULINO       SOLTERO
# 5849                   A PIE  28.0  MASCULINO       SOLTERO
# 6315                   A PIE  61.0  MASCULINO   UNION LIBRE
# 7885                   A PIE  41.0  MASCULINO   UNION LIBRE
# 8094    PASAJERO MOTOCICLETA  43.0  MASCULINO   UNION LIBRE
# 8183                   A PIE  38.0  MASCULINO       SOLTERO
# 8223                   A PIE  23.0  MASCULINO       SOLTERO
# 9033   CONDUCTOR MOTOCICLETA  26.0  MASCULINO   UNION LIBRE
# 9751                   A PIE  37.0  MASCULINO      SEPARADO
# 10205                  A PIE  27.0  MASCULINO       SOLTERO
# 10625                  A PIE  31.0  MASCULINO   UNION LIBRE
# 10689                  A PIE  25.0   FEMENINO       SOLTERO
# 10959                  A PIE  26.0  MASCULINO   UNION LIBRE
# 11020                  A PIE  40.0  MASCULINO   UNION LIBRE
# 11740   PASAJERO MOTOCICLETA  40.0  MASCULINO   UNION LIBRE
# 11957                  A PIE  30.0   FEMENINO        CASADO
# 12206                  A PIE  21.0  MASCULINO       SOLTERO
#
#             CLASE EMPLEADO     PROFESION   ESCOLARIDAD     PAIS NACE  \
# 172      EMPLEADO EJERCITO  NO REPORTADO    SECUNDARIA      COLOMBIA
# 1114         INDEPENDIENTE  NO REPORTADO      PRIMARIA      COLOMBIA
# 2119   EMPLEADO PARTICULAR  NO REPORTADO    SECUNDARIA      COLOMBIA
# 3309         INDEPENDIENTE  NO REPORTADO      PRIMARIA      COLOMBIA
# 3409         INDEPENDIENTE  NO REPORTADO    SECUNDARIA      COLOMBIA
# 3588           DESEMPLEADO  NO REPORTADO  NO REPORTADO  NO REPORTADO
# 4565         INDEPENDIENTE  NO REPORTADO    SECUNDARIA      COLOMBIA
# 4587   EMPLEADO PARTICULAR  NO REPORTADO    SECUNDARIA      COLOMBIA
# 4971         INDEPENDIENTE  NO REPORTADO    SECUNDARIA      COLOMBIA
# 5372            NO REPORTA  NO REPORTADO  NO REPORTADO  NO REPORTADO
# 5532   EMPLEADO PARTICULAR  NO REPORTADO    SECUNDARIA      COLOMBIA
# 5834           DESEMPLEADO  NO REPORTADO      PRIMARIA      COLOMBIA
# 5849           DESEMPLEADO  NO REPORTADO    ANALFABETA      COLOMBIA
# 6315   EMPLEADO PARTICULAR  NO REPORTADO      PRIMARIA      COLOMBIA
# 7885   EMPLEADO PARTICULAR  NO REPORTADO    SECUNDARIA      COLOMBIA
# 8094         INDEPENDIENTE  NO REPORTADO    SECUNDARIA      COLOMBIA
# 8183         INDEPENDIENTE  NO REPORTADO    SECUNDARIA      COLOMBIA
# 8223            AGRICULTOR  NO REPORTADO      PRIMARIA      COLOMBIA
# 9033   EMPLEADO PARTICULAR  NO REPORTADO    SECUNDARIA      COLOMBIA
# 9751   EMPLEADO PARTICULAR  NO REPORTADO    SECUNDARIA      COLOMBIA
# 10205          DESEMPLEADO  NO REPORTADO      PRIMARIA      COLOMBIA
# 10625  EMPLEADO PARTICULAR  NO REPORTADO    SECUNDARIA      COLOMBIA
# 10689           ESTUDIANTE  NO REPORTADO    SECUNDARIA      COLOMBIA
# 10959     AFRODESCENDIENTE  NO REPORTADO    SECUNDARIA      COLOMBIA
# 11020        INDEPENDIENTE  NO REPORTADO      PRIMARIA      COLOMBIA
# 11740  EMPLEADO PARTICULAR  NO REPORTADO      PRIMARIA      COLOMBIA
# 11957  EMPLEADO PARTICULAR  NO REPORTADO    SECUNDARIA      COLOMBIA
# 12206  EMPLEADO PARTICULAR  NO REPORTADO    SECUNDARIA      COLOMBIA
#
#        CODIGO DANE  AÑO DE NACIMIENTO  CÉDULA                      CORREO  \
# 172     50330000.0             1991.0  68-021        oohghd8899@gmail.com
# 1114     8001000.0             1986.0  14-017  correo5853@colombia.gov.co
# 2119    76001000.0             1995.0  97-531  ohbqrk3631@unidatos.edu.co
# 3309    18001000.0             1992.0  34-866  pdkqur8407@unidatos.edu.co
# 3409    23660000.0             1966.0  49-618  fdbbeo6751@unidatos.edu.co
# 3588    13001000.0             1970.0  18-803  diebuo5651@unidatos.edu.co
# 4565    85139000.0             1988.0  92-874        jgffkn2333@gmail.com
# 4587    76111000.0             1990.0  27-345        rjnpih6160@gmail.com
# 4971    76001000.0             1980.0  55-963        gmfrkj7682@gmail.com
# 5372    52001000.0             1995.0  63-185  blhqee9596@unidatos.edu.co
# 5532    25899000.0             1970.0  98-100  gulnti6068@unidatos.edu.co
# 5834    76001000.0             1995.0  31-949   correo106@unidatos.edu.co
# 5849     5001000.0             1987.0  47-307  mhnpbt1616@unidatos.edu.co
# 6315    76001000.0             1954.0  89-381  nktafs3674@unidatos.edu.co
# 7885    17486000.0             1974.0  85-455  mdidfd3568@unidatos.edu.co
# 8094    23090000.0             1972.0  60-436        unpnst4035@gmail.com
# 8183    11001000.0             1977.0  35-223  mguhkp8332@unidatos.edu.co
# 8223     5664000.0             1992.0  58-651        ptcjrg1586@gmail.com
# 9033    23001000.0             1989.0  57-014   correo790@unidatos.edu.co
# 9751    76403000.0             1978.0  51-841  buuglr2678@unidatos.edu.co
# 10205   66400000.0             1988.0  42-472  eihgoo6734@unidatos.edu.co
# 10625   63001000.0             1984.0  85-267  ntmqbr5389@unidatos.edu.co
# 10689   19001000.0             1990.0  40-311  eljcip8688@unidatos.edu.co
# 10959    5001000.0             1989.0  50-205   correo563@unidatos.edu.co
# 11020   47189000.0             1975.0  52-937  emfska3600@unidatos.edu.co
# 11740    5893000.0             1975.0  86-483        isbfod2768@gmail.com
# 11957    5001000.0             1985.0  85-604  ncqoit2394@unidatos.edu.co
# 12206   76001000.0             1994.0  12-861        ppriho5465@gmail.com
#
#       CÉDULA1 CÉDULA2
# 172        68     021
# 1114       14     017
# 2119       97     531
# 3309       34     866
# 3409       49     618
# 3588       18     803
# 4565       92     874
# 4587       27     345
# 4971       55     963
# 5372       63     185
# 5532       98     100
# 5834       31     949
# 5849       47     307
# 6315       89     381
# 7885       85     455
# 8094       60     436
# 8183       35     223
# 8223       58     651
# 9033       57     014
# 9751       51     841
# 10205      42     472
# 10625      85     267
# 10689      40     311
# 10959      50     205
# 11020      52     937
# 11740      86     483
# 11957      85     604
# 12206      12     861

# %% [markdown]
# <span style="color:red">TODO: Make something similar to check and fix the "CORREO" column (PATTERN: 4 digits before the @, only .edu.co and .com domains are allowed)</span>

# %%
# Partimos por quitarle los espacios a los correos.
homicides_df["CORREO"].str.strip()

# Luego realizo un split del correo para poder analizar por aparte el dominio y el nombre del correo. 
correo_malformed = homicides_df["CORREO"].str.split(pat='@',n=2, expand=True)
correo_malformed.rename(columns={0:"Direccion",1:"Dominio"}, inplace=True)

# Identifico los correos cuyo dominio es diferente de edu.co o .com . Esto nos da 1.011 registros.

correo_malformed['DominioEDU'] = correo_malformed['Dominio'].str.contains("edu.co", case=False, regex=True)
correo_malformed['DominioCOM'] = correo_malformed['Dominio'].str.contains(".com", case=False, regex=True)
flt = correo_malformed['DominioEDU']==False
correo_malformed = correo_malformed[flt]
flt = correo_malformed['DominioCOM']==False
correo_malformed = correo_malformed[flt]
correo_malformed
# Out:
#         Direccion          Dominio  DominioEDU  DominioCOM
# 36     correo4714  colombia.gov.co       False       False
# 47     correo8297  colombia.gov.co       False       False
# 55     correo7285  colombia.gov.co       False       False
# 84     correo8342  colombia.gov.co       False       False
# 104    correo6479  colombia.gov.co       False       False
# ...           ...              ...         ...         ...
# 12370  correo7745  colombia.gov.co       False       False
# 12378  correo9786  colombia.gov.co       False       False
# 12380  correo8859  colombia.gov.co       False       False
# 12387  correo3558  colombia.gov.co       False       False
# 12395  correo4352  colombia.gov.co       False       False
#
# [1011 rows x 4 columns]

# %%
# Dado que no hay una forma de solucionarlo y se debe arreglar. Para que solo tenga 4 caracteres antes del @ tomaré los últimos 4 digitos y el dominio será reemplazado por 
# por gmail.com

correo_malformed['CorreoCorrecto']=correo_malformed['Direccion'].str[-4:]+"@gmail.com"
homicides_df["CORREO"].update(correo_malformed['CorreoCorrecto'])
homicides_df
# Out:
#                     FECHA DEPARTAMENTO      MUNICIPIO     DIA  \
# 0     2021-01-01 06:00:00    ANTIOQUIA          AMAGÁ  Jueves
# 1     2021-01-01 09:00:00    ANTIOQUIA        BARBOSA  Jueves
# 2     2021-01-01 19:00:00    ANTIOQUIA       EL BAGRE  Jueves
# 3     2021-01-01 11:20:00    ANTIOQUIA         JARDÍN  Jueves
# 4     2021-01-01 15:00:00    ANTIOQUIA  MEDELLÍN (CT)   Juees
# ...                   ...          ...            ...     ...
# 12394 2021-12-31 15:42:00        VALLE     EL CERRITO  Jueves
# 12395 2021-12-31 19:04:00        VALLE      LA CUMBRE  Jueves
# 12396 2021-12-31 22:35:00        VALLE        PALMIRA  Jueves
# 12397 2021-12-31 14:30:00        VALLE         ZARZAL  Jueves
# 12398 2021-12-31 22:55:00      VICHADA       CUMARIBO  Jueves
#
#                          BARRIO    ZONA                      CLASE DE SITIO  \
# 0                     EL VOLCAN   RURAL                              TIENDA
# 1                VDA. MATASANOS   RURAL                       VIAS PUBLICAS
# 2                 PUERTO CLAVER   RURAL                  FINCAS Y SIMILARES
# 3                    CRISTIANIA   RURAL                  FINCAS Y SIMILARES
# 4      PICACHITO CNO REPORTADO6  URBANA  FRENTE A RESIDENCIAS - VIA PUBLICA
# ...                         ...     ...                                 ...
# 12394              LA ESPERANZA  URBANA                       VIAS PUBLICAS
# 12395           CGTO BITACO E27   RURAL                       VIAS PUBLICAS
# 12396                    LORETO  URBANA                       VIAS PUBLICAS
# 12397         URB. EL ZARZALITO  URBANA                       VIAS PUBLICAS
# 12398                 EL CENTRO  URBANA                          HOSPITALES
#
#         ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO  \
# 0        ARMA BLANCA         A PIE         A PIE  44.0  MASCULINO
# 1        ARMA BLANCA         A PIE         A PIE  30.0  MASCULINO
# 2        ARMA BLANCA         A PIE         A PIE  33.0  MASCULINO
# 3        ARMA BLANCA         A PIE         A PIE  40.0  MASCULINO
# 4       CONTUNDENTES         A PIE         A PIE  66.0  MASCULINO
# ...              ...           ...           ...   ...        ...
# 12394  ARMA DE FUEGO         A PIE         A PIE  53.0   FEMENINO
# 12395  ARMA DE FUEGO         A PIE         A PIE  58.0  MASCULINO
# 12396  ARMA DE FUEGO         A PIE         A PIE  18.0   FEMENINO
# 12397  ARMA DE FUEGO         A PIE         A PIE  27.0  MASCULINO
# 12398    ARMA BLANCA         A PIE         A PIE  23.0  MASCULINO
#
#       ESTADO CIVIL       CLASE EMPLEADO     PROFESION ESCOLARIDAD  \
# 0           CASADO        INDEPENDIENTE  NO REPORTADO    PRIMARIA
# 1          SOLTERO          DESEMPLEADO  NO REPORTADO  SECUNDARIA
# 2      UNION LIBRE           AGRICULTOR  NO REPORTADO    PRIMARIA
# 3           CASADO           AGRICULTOR  NO REPORTADO    PRIMARIA
# 4      UNION LIBRE          DESEMPLEADO  NO REPORTADO    PRIMARIA
# ...            ...                  ...           ...         ...
# 12394       CASADO  EMPLEADO PARTICULAR  NO REPORTADO    PRIMARIA
# 12395  UNION LIBRE           AGRICULTOR  NO REPORTADO    PRIMARIA
# 12396      SOLTERO           ESTUDIANTE  NO REPORTADO  SECUNDARIA
# 12397      SOLTERO  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA
# 12398      SOLTERO        INDEPENDIENTE  NO REPORTADO  SECUNDARIA
#
#           PAIS NACE  CODIGO DANE  AÑO DE NACIMIENTO  CÉDULA  \
# 0          COLOMBIA    5030000.0             1971.0  42-908
# 1      NO REPORTADO    5079000.0             1985.0  15-183
# 2          COLOMBIA    5250000.0             1982.0  84-786
# 3          COLOMBIA    5364000.0             1975.0  31-289
# 4          COLOMBIA    5001000.0             1949.0  66-363
# ...             ...          ...                ...     ...
# 12394      COLOMBIA   76248000.0             1962.0  39-658
# 12395      COLOMBIA   76377000.0             1957.0  39-442
# 12396      COLOMBIA   76520000.0             1997.0  25-368
# 12397      COLOMBIA   76895000.0             1988.0  62-735
# 12398      COLOMBIA   99773000.0             1992.0  47-126
#
#                            CORREO
# 0      agbnqg2122@unidatos.edu.co
# 1            rbkeui3584@gmail.com
# 2      aorkhf9155@unidatos.edu.co
# 3      dhtemr6623@unidatos.edu.co
# 4      artatj9268@unidatos.edu.co
# ...                           ...
# 12394        nggiso7664@gmail.com
# 12395              4352@gmail.com
# 12396  fktatq9245@unidatos.edu.co
# 12397        gafkup6393@gmail.com
# 12398   correo736@unidatos.edu.co
#
# [12399 rows x 21 columns]

# %%
# Showing different values for "DIA" column
homicides_df["DIA"].unique()
# Out:
# array(['Jueves', 'Juees', 'Jueces', 'juves', 'Juevrs', 'Viernes',
#        'Viermes', 'iernes', 'virnes', 'Vierens', 'Sábado', 'Sabadi',
#        'Sabado', 'sábad', 'Sávado', 'Ssbado', 'Domingo', 'Domungo',
#        'Doningo', 'domungo', 'Lunes', 'lune', 'Luns', 'Lumes', 'kunes',
#        'Lnues', 'Martes', 'Mates', 'Marte', 'mates', 'Miércoles',
#        'Miwrcoles', 'Mircoles', 'Voernes', 'domnigo', 'Maryes',
#        'Miercoles', 'miércles', 'Dominog', 'Msrtes', 'Mirrcoles'],
#       dtype=object)

# %%
# Calculating the distance between two words using the Levenshtein method
pylev.levenshtein('sábado', 'sabaod')
# Out:
# 3

# %%
pylev.levenshtein('sábado', 'viernes')
# Out:
# 7

# %% [markdown]
# <span style="color:red">TODO: Create a function to fix the digitation errors for "DIA" column.</span>

# %%
# Primero, voy a experimentar un poco con la función verificando valores como Viernes con iernes
pylev.levenshtein('viernes', 'iernes')
pylev.levenshtein('Jueves', 'Juees')
pylev.levenshtein('Lunes', 'Juees')
# Out:
# 2

# %%
# Convierto el día a mayusculas para eliminar posibles diferencias ocasionadas por las letras capitales

homicides_df["DIA"]=homicides_df["DIA"].str.upper()
homicides_df["DIA"].unique()
# Out:
# array(['JUEVES', 'JUEES', 'JUECES', 'JUVES', 'JUEVRS', 'VIERNES',
#        'VIERMES', 'IERNES', 'VIRNES', 'VIERENS', 'SÁBADO', 'SABADI',
#        'SABADO', 'SÁBAD', 'SÁVADO', 'SSBADO', 'DOMINGO', 'DOMUNGO',
#        'DONINGO', 'LUNES', 'LUNE', 'LUNS', 'LUMES', 'KUNES', 'LNUES',
#        'MARTES', 'MATES', 'MARTE', 'MIÉRCOLES', 'MIWRCOLES', 'MIRCOLES',
#        'VOERNES', 'DOMNIGO', 'MARYES', 'MIERCOLES', 'MIÉRCLES', 'DOMINOG',
#        'MSRTES', 'MIRRCOLES'], dtype=object)

# %%
# Se define una función utilizando el metodo Levenshtein para corregir las diferencias solo en grado 1. Se hace paulatino para que palabras como Juees que no dista
# mucho del Lunes, pueda ser corregida por Jueves y no por el primero que encuentre con grado mayor.

def corregirErrorDiaGrado1(x):
    distancia = 1
    if pylev.levenshtein('LUNES', x) <= distancia: 
        return 'LUNES'
    elif pylev.levenshtein('MARTES', x) <= distancia:
        return 'MARTES'
    elif pylev.levenshtein('MIÉRCOLES', x) <= distancia:
        return 'MIERCOLES'
    elif pylev.levenshtein('JUEVES', x) <= distancia:
        return 'JUEVES'
    elif pylev.levenshtein('VIERNES', x) <= distancia:
        return 'VIERNES'
    elif pylev.levenshtein('SÁBADO', x) <= distancia:
        return 'SABADO'
    elif pylev.levenshtein('DOMINGO', x) <= distancia:
        return 'DOMINGO'
    else:
        return x

homicides_df["DIA"]=homicides_df["DIA"].apply(corregirErrorDiaGrado1)

# %%
homicides_df["DIA"].unique()
# Out:
# array(['JUEVES', 'VIERNES', 'VIERENS', 'SABADO', 'SABADI', 'DOMINGO',
#        'LUNES', 'LNUES', 'MARTES', 'MIERCOLES', 'DOMNIGO', 'DOMINOG'],
#       dtype=object)

# %%
# Se define una función utilizando el metodo Levenshtein para corregir las diferencias en grado 2.

def corregirErrorDiaGrado2(x):
    distancia = 2
    if pylev.levenshtein('LUNES', x) <= distancia: 
        return 'LUNES'
    elif pylev.levenshtein('MARTES', x) <= distancia:
        return 'MARTES'
    elif pylev.levenshtein('MIÉRCOLES', x) <= distancia:
        return 'MIERCOLES'
    elif pylev.levenshtein('JUEVES', x) <= distancia:
        return 'JUEVES'
    elif pylev.levenshtein('VIERNES', x) <= distancia:
        return 'VIERNES'
    elif pylev.levenshtein('SÁBADO', x) <= distancia:
        return 'SABADO'
    elif pylev.levenshtein('DOMINGO', x) <= distancia:
        return 'DOMINGO'
    else:
        return x

homicides_df["DIA"]=homicides_df["DIA"].apply(corregirErrorDiaGrado2)
homicides_df["DIA"].unique()
# Out:
# array(['JUEVES', 'VIERNES', 'SABADO', 'DOMINGO', 'LUNES', 'MARTES',
#        'MIERCOLES'], dtype=object)

# %%
homicides_df[["AÑO DE NACIMIENTO", "EDAD"]].head(10)
# Out:
#    AÑO DE NACIMIENTO  EDAD
# 0             1971.0  44.0
# 1             1985.0  30.0
# 2             1982.0  33.0
# 3             1975.0  40.0
# 4             1949.0  66.0
# 5             1973.0  42.0
# 6             1990.0  25.0
# 7             1978.0  37.0
# 8             1990.0  25.0
# 9             1985.0  30.0

# %% [markdown]
# <span style="color:red">TODO: Fix the "AÑO DE NACIMIENTO" column using the column "EDAD".</span>

# %%
homicides_df["AÑO DE NACIMIENTO"]=2022-homicides_df["EDAD"]

# %%
homicides_df
# Out:
#                     FECHA DEPARTAMENTO      MUNICIPIO     DIA  \
# 0     2021-01-01 06:00:00    ANTIOQUIA          AMAGÁ  JUEVES
# 1     2021-01-01 09:00:00    ANTIOQUIA        BARBOSA  JUEVES
# 2     2021-01-01 19:00:00    ANTIOQUIA       EL BAGRE  JUEVES
# 3     2021-01-01 11:20:00    ANTIOQUIA         JARDÍN  JUEVES
# 4     2021-01-01 15:00:00    ANTIOQUIA  MEDELLÍN (CT)  JUEVES
# ...                   ...          ...            ...     ...
# 12394 2021-12-31 15:42:00        VALLE     EL CERRITO  JUEVES
# 12395 2021-12-31 19:04:00        VALLE      LA CUMBRE  JUEVES
# 12396 2021-12-31 22:35:00        VALLE        PALMIRA  JUEVES
# 12397 2021-12-31 14:30:00        VALLE         ZARZAL  JUEVES
# 12398 2021-12-31 22:55:00      VICHADA       CUMARIBO  JUEVES
#
#                          BARRIO    ZONA                      CLASE DE SITIO  \
# 0                     EL VOLCAN   RURAL                              TIENDA
# 1                VDA. MATASANOS   RURAL                       VIAS PUBLICAS
# 2                 PUERTO CLAVER   RURAL                  FINCAS Y SIMILARES
# 3                    CRISTIANIA   RURAL                  FINCAS Y SIMILARES
# 4      PICACHITO CNO REPORTADO6  URBANA  FRENTE A RESIDENCIAS - VIA PUBLICA
# ...                         ...     ...                                 ...
# 12394              LA ESPERANZA  URBANA                       VIAS PUBLICAS
# 12395           CGTO BITACO E27   RURAL                       VIAS PUBLICAS
# 12396                    LORETO  URBANA                       VIAS PUBLICAS
# 12397         URB. EL ZARZALITO  URBANA                       VIAS PUBLICAS
# 12398                 EL CENTRO  URBANA                          HOSPITALES
#
#         ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO  \
# 0        ARMA BLANCA         A PIE         A PIE  44.0  MASCULINO
# 1        ARMA BLANCA         A PIE         A PIE  30.0  MASCULINO
# 2        ARMA BLANCA         A PIE         A PIE  33.0  MASCULINO
# 3        ARMA BLANCA         A PIE         A PIE  40.0  MASCULINO
# 4       CONTUNDENTES         A PIE         A PIE  66.0  MASCULINO
# ...              ...           ...           ...   ...        ...
# 12394  ARMA DE FUEGO         A PIE         A PIE  53.0   FEMENINO
# 12395  ARMA DE FUEGO         A PIE         A PIE  58.0  MASCULINO
# 12396  ARMA DE FUEGO         A PIE         A PIE  18.0   FEMENINO
# 12397  ARMA DE FUEGO         A PIE         A PIE  27.0  MASCULINO
# 12398    ARMA BLANCA         A PIE         A PIE  23.0  MASCULINO
#
#       ESTADO CIVIL       CLASE EMPLEADO     PROFESION ESCOLARIDAD  \
# 0           CASADO        INDEPENDIENTE  NO REPORTADO    PRIMARIA
# 1          SOLTERO          DESEMPLEADO  NO REPORTADO  SECUNDARIA
# 2      UNION LIBRE           AGRICULTOR  NO REPORTADO    PRIMARIA
# 3           CASADO           AGRICULTOR  NO REPORTADO    PRIMARIA
# 4      UNION LIBRE          DESEMPLEADO  NO REPORTADO    PRIMARIA
# ...            ...                  ...           ...         ...
# 12394       CASADO  EMPLEADO PARTICULAR  NO REPORTADO    PRIMARIA
# 12395  UNION LIBRE           AGRICULTOR  NO REPORTADO    PRIMARIA
# 12396      SOLTERO           ESTUDIANTE  NO REPORTADO  SECUNDARIA
# 12397      SOLTERO  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA
# 12398      SOLTERO        INDEPENDIENTE  NO REPORTADO  SECUNDARIA
#
#           PAIS NACE  CODIGO DANE  AÑO DE NACIMIENTO  CÉDULA  \
# 0          COLOMBIA    5030000.0             1978.0  42-908
# 1      NO REPORTADO    5079000.0             1992.0  15-183
# 2          COLOMBIA    5250000.0             1989.0  84-786
# 3          COLOMBIA    5364000.0             1982.0  31-289
# 4          COLOMBIA    5001000.0             1956.0  66-363
# ...             ...          ...                ...     ...
# 12394      COLOMBIA   76248000.0             1969.0  39-658
# 12395      COLOMBIA   76377000.0             1964.0  39-442
# 12396      COLOMBIA   76520000.0             2004.0  25-368
# 12397      COLOMBIA   76895000.0             1995.0  62-735
# 12398      COLOMBIA   99773000.0             1999.0  47-126
#
#                            CORREO
# 0      agbnqg2122@unidatos.edu.co
# 1            rbkeui3584@gmail.com
# 2      aorkhf9155@unidatos.edu.co
# 3      dhtemr6623@unidatos.edu.co
# 4      artatj9268@unidatos.edu.co
# ...                           ...
# 12394        nggiso7664@gmail.com
# 12395              4352@gmail.com
# 12396  fktatq9245@unidatos.edu.co
# 12397        gafkup6393@gmail.com
# 12398   correo736@unidatos.edu.co
#
# [12399 rows x 21 columns]
